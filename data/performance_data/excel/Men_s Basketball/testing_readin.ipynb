# %%
import pandas as pd

# %%
df = pd.read_csv("csv/2016 Men's Basketball.csv")
df.head(20)
# Out:
#    Overall Record: 27-6   Conf: 17-3   Home: 15-3   Away: 9-3   Neutral: 3-0  \
# 0                                                   #
# 1                                                  13
# 2                                                  44
# 3                                                  14
# 4                                                  01
# 5                                                  11
# 6                                                  05
# 7                                                  10
# 8                                                  22
# 9                                                  24
# 10                                                 33
# 11                                                 15
# 12                                                 03
# 13                                                 25
# 14                                              Total
# 15                                          Opponents
# ...

# %%
df = pd.read_excel("2016 Men's Basketball.xlsx")
df.head(20)
# Out:
#    Overall Record: 27-6   Conf: 17-3   Home: 15-3   Away: 9-3   Neutral: 3-0  \
# 0                                                   #
# 1                                                  13
# 2                                                  44
# 3                                                  14
# 4                                                   1
# 5                                                  11
# 6                                                   5
# 7                                                  10
# 8                                                  22
# 9                                                  24
# 10                                                 33
# 11                                                 15
# 12                                                  3
# 13                                                 25
# 14                                              Total
# 15                                          Opponents
# ...
